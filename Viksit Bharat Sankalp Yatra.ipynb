# %% [markdown]
# ##### Hamara Sankalp Viksit Bharat is a nationwide campaign to raise awareness through outreach activities to achieve saturation of schemes of Govt. of India across the country covering all Gram Panchayats, Nagar Panchayats and Urban Local Bodies with the objectives of:
# * Reaching the unreached - reach out to the vulnerable who are eligible under various schemes but have not availed benefit so far
# * Dissemination of information and generating awareness about schemes
# * Learning from the citizens - Interaction with beneficiaries of government schemes through their personal stories/ experience sharing
# * Enrolment of potential beneficiaries through details ascertained during the Yatra.
# The campaign is being taken up by adopting a whole of government approach with active involvement of various Ministries/Departments of Government of India, State Governments, Central Govt. Organizations and Institutions to ensure the widest possible participation of all concerned for the benefit of Citizens of the country and to realize the vision of Viksit Bharat.

# %% [markdown]
# ##### Here is a Brief Information about Camp Organized in the area of Bhopal Municipal Corporation

# %%
import pandas as pd
import numpy as np
import folium
from folium import plugins

# %%
df = pd.read_excel('VBSY.xlsx')
print('data successfully read into pandas dataframe')
# Out:
# data successfully read into pandas dataframe

# %%
df.head()
# Out:
#         Date     Time Zone    Ward Camp Incharge Name   \
# 0 2023-12-17  Morning     1    3,4              Vikram
# 1 2023-12-17  Evening     1      5         Bhagiraath
# 2 2023-12-18  Morning     2   7,10             Vishal
# 3 2023-12-18  Evening    12     44             Mukesh
# 4 2023-12-19  Morning     5  22,23         Arbaaj Khan
#
#    Camp Incharge Mob. No.                   Camp Location Address    Latitude  \
# 0               9424499901               Sehore Naka Visarjan Ghat  23.269873
# 1               9425601305         Dashahera Maidan School ke Pass  23.272666
# 2               9424499902                         yogseva kendra   23.271694
# 3               9424499912  acharya narendra nagar, hanuman mandir  23.247364
# 4               9425601322                     Hathikhana chouraha  23.252569
#
#    Longitude Vidhan Sabha
# 0  77.327614         Huzur
# 1  77.336770         Huzur
# 2  77.379792         Uttar
# 3  77.436113        Narela
# 4  77.404444        Madhya

# %%
# remove extra space from columns
df.columns = [x.strip() for x in df.columns]

# %%
df['Camp Location Address'] = df['Camp Location Address'].str.capitalize()
df.head()
# Out:
#         Date     Time Zone   Ward Camp Incharge Name  Camp Incharge Mob. No.  \
# 0 2023-12-17  Morning    1    3,4             Vikram              9424499901
# 1 2023-12-17  Evening    1      5        Bhagiraath               9425601305
# 2 2023-12-18  Morning    2   7,10            Vishal               9424499902
# 3 2023-12-18  Evening   12     44            Mukesh               9424499912
# 4 2023-12-19  Morning    5  22,23        Arbaaj Khan              9425601322
#
#                     Camp Location Address   Latitude  Longitude Vidhan Sabha
# 0               Sehore naka visarjan ghat  23.269873  77.327614        Huzur
# 1         Dashahera maidan school ke pass  23.272666  77.336770        Huzur
# 2                         Yogseva kendra   23.271694  77.379792        Uttar
# 3  Acharya narendra nagar, hanuman mandir  23.247364  77.436113       Narela
# 4                     Hathikhana chouraha  23.252569  77.404444       Madhya

# %%
vidhansabha_wise = df.groupby(['Vidhan Sabha'])['Camp Location Address'].count().to_frame().reset_index()

# %%
vidhansabha_wise
# Out:
#        Vidhan Sabha  Camp Location Address
# 0  Dakshin Pashchim                     13
# 1        Govindpura                     18
# 2             Huzur                      8
# 3            Madhya                     10
# 4            Narela                     17
# 5             Uttar                      8

# %%
bhopal_progress_df = pd.read_excel('bhopal_progress.xlsx')
print('data successfully read into pandas dataframe')
# Out:
# data successfully read into pandas dataframe

# %%
bhopal_progress_df.head()
# Out:
#   Vidhan Sabha       Date      Shift                         Location  \
# 0        Huzur 2023-12-17    Morning        SEHORE NAKA VISARJAN GHAT
# 1        Huzur 2023-12-17  Afternoon  DASHAHERA MAIDAN SCHOOL KE PASS
# 2        Uttar 2023-12-18    Morning                  YOGSEVA KENDRA
# 3       Narela 2023-12-18  Afternoon           ACHARYA NARENDRA NAGAR
# 4       Madhya 2023-12-19    Morning              HATHIKHANA CHOURAHA
#
#    Total People Attendance  Men Attended  Women Attended  \
# 0                     2285           990            1295
# 1                     2050           865            1185
# 2                     2104           968            1136
# 3                     2109          1023            1086
# 4                      552           181             371
#
#    Registered for PM SWANIDHI CAMP  People Attended Health Camp  \
# 0                              220                          350
# 1                              236                          386
# 2                              245                          345
# 3                              203                          304
# 4                               67                          140
#
#    People Availed Ayushman card camp  Registration for PM - Ujjwala Yojna  \
# 0                                 46                                   15
# 1                                 39                                   36
# 2                                 40                                   48
# 3                                 34                                   17
# 4                                 58                                   55
#
#    People for Aadhar card camp  Total People taking Sankalp Publicly
# 0                           98                                  1555
# 1                           74                                  1268
# 2                           82                                  1482
# 3                           65                                  1365
# 4                           42                                   117

# %%
bhopal_progress_df.shape
# Out:
# (74, 13)

# %%
# remove extra space from location column
bhopal_progress_df['Location'] = [x.strip() for x in bhopal_progress_df['Location']]
bhopal_progress_df['Location'] = bhopal_progress_df['Location'].str.capitalize()

# %%
bhopal_progress_df.head()
# Out:
#   Vidhan Sabha       Date      Shift                         Location  \
# 0        Huzur 2023-12-17    Morning        Sehore naka visarjan ghat
# 1        Huzur 2023-12-17  Afternoon  Dashahera maidan school ke pass
# 2        Uttar 2023-12-18    Morning                   Yogseva kendra
# 3       Narela 2023-12-18  Afternoon           Acharya narendra nagar
# 4       Madhya 2023-12-19    Morning              Hathikhana chouraha
#
#    Total People Attendance  Men Attended  Women Attended  \
# 0                     2285           990            1295
# 1                     2050           865            1185
# 2                     2104           968            1136
# 3                     2109          1023            1086
# 4                      552           181             371
#
#    Registered for PM SWANIDHI CAMP  People Attended Health Camp  \
# 0                              220                          350
# 1                              236                          386
# 2                              245                          345
# 3                              203                          304
# 4                               67                          140
#
#    People Availed Ayushman card camp  Registration for PM - Ujjwala Yojna  \
# 0                                 46                                   15
# 1                                 39                                   36
# 2                                 40                                   48
# 3                                 34                                   17
# 4                                 58                                   55
#
#    People for Aadhar card camp  Total People taking Sankalp Publicly
# 0                           98                                  1555
# 1                           74                                  1268
# 2                           82                                  1482
# 3                           65                                  1365
# 4                           42                                   117

# %%
bhopal_progress_df['Date'] = bhopal_progress_df['Date'].dt.strftime('%d-%m-%Y')
vs_dict = bhopal_progress_df.to_dict(orient='records')
vs_dict
# Out:
# [{'Vidhan Sabha': 'Huzur',
#   'Date': '17-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Sehore naka visarjan ghat',
#   'Total People Attendance': 2285,
#   'Men Attended': 990,
#   'Women Attended': 1295,
#   'Registered for PM SWANIDHI CAMP': 220,
#   'People Attended Health Camp': 350,
#   'People Availed Ayushman card camp': 46,
#   'Registration for PM - Ujjwala Yojna': 15,
#   'People for Aadhar card camp': 98,
#   'Total People taking Sankalp Publicly': 1555},
#  {'Vidhan Sabha': 'Huzur',
#   'Date': '17-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Dashahera maidan school ke pass',
#   'Total People Attendance': 2050,
#   'Men Attended': 865,
#   'Women Attended': 1185,
#   'Registered for PM SWANIDHI CAMP': 236,
#   'People Attended Health Camp': 386,
#   'People Availed Ayushman card camp': 39,
#   'Registration for PM - Ujjwala Yojna': 36,
#   'People for Aadhar card camp': 74,
#   'Total People taking Sankalp Publicly': 1268},
#  {'Vidhan Sabha': 'Uttar',
#   'Date': '18-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Yogseva kendra',
#   'Total People Attendance': 2104,
#   'Men Attended': 968,
#   'Women Attended': 1136,
#   'Registered for PM SWANIDHI CAMP': 245,
#   'People Attended Health Camp': 345,
#   'People Availed Ayushman card camp': 40,
#   'Registration for PM - Ujjwala Yojna': 48,
#   'People for Aadhar card camp': 82,
#   'Total People taking Sankalp Publicly': 1482},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '18-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Acharya narendra nagar',
#   'Total People Attendance': 2109,
#   'Men Attended': 1023,
#   'Women Attended': 1086,
#   'Registered for PM SWANIDHI CAMP': 203,
#   'People Attended Health Camp': 304,
#   'People Availed Ayushman card camp': 34,
#   'Registration for PM - Ujjwala Yojna': 17,
#   'People for Aadhar card camp': 65,
#   'Total People taking Sankalp Publicly': 1365},
#  {'Vidhan Sabha': 'Madhya',
#   'Date': '19-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Hathikhana chouraha',
#   'Total People Attendance': 552,
#   'Men Attended': 181,
#   'Women Attended': 371,
#   'Registered for PM SWANIDHI CAMP': 67,
#   'People Attended Health Camp': 140,
#   'People Availed Ayushman card camp': 58,
#   'Registration for PM - Ujjwala Yojna': 55,
#   'People for Aadhar card camp': 42,
#   'Total People taking Sankalp Publicly': 117},
#  {'Vidhan Sabha': 'Madhya',
#   'Date': '19-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Ward office 51',
#   'Total People Attendance': 2146,
#   'Men Attended': 873,
#   'Women Attended': 1273,
#   'Registered for PM SWANIDHI CAMP': 268,
#   'People Attended Health Camp': 372,
#   'People Availed Ayushman card camp': 52,
#   'Registration for PM - Ujjwala Yojna': 23,
#   'People for Aadhar card camp': 84,
#   'Total People taking Sankalp Publicly': 1973},
#  {'Vidhan Sabha': 'Uttar',
#   'Date': '20-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Nariyal kheda',
#   'Total People Attendance': 2302,
#   'Men Attended': 954,
#   'Women Attended': 1348,
#   'Registered for PM SWANIDHI CAMP': 301,
#   'People Attended Health Camp': 576,
#   'People Availed Ayushman card camp': 74,
#   'Registration for PM - Ujjwala Yojna': 34,
#   'People for Aadhar card camp': 97,
#   'Total People taking Sankalp Publicly': 2153},
#  {'Vidhan Sabha': 'Uttar',
#   'Date': '20-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Hawa mahal',
#   'Total People Attendance': 2126,
#   'Men Attended': 852,
#   'Women Attended': 1274,
#   'Registered for PM SWANIDHI CAMP': 254,
#   'People Attended Health Camp': 389,
#   'People Availed Ayushman card camp': 64,
#   'Registration for PM - Ujjwala Yojna': 59,
#   'People for Aadhar card camp': 87,
#   'Total People taking Sankalp Publicly': 1812},
#  {'Vidhan Sabha': 'Uttar',
#   'Date': '21-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Teela jamalpura shoping center',
#   'Total People Attendance': 2073,
#   'Men Attended': 858,
#   'Women Attended': 1215,
#   'Registered for PM SWANIDHI CAMP': 243,
#   'People Attended Health Camp': 327,
#   'People Availed Ayushman card camp': 48,
#   'Registration for PM - Ujjwala Yojna': 41,
#   'People for Aadhar card camp': 94,
#   'Total People taking Sankalp Publicly': 1647},
#  {'Vidhan Sabha': ' Madhya',
#   'Date': '21-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Shahapura lake',
#   'Total People Attendance': 2010,
#   'Men Attended': 947,
#   'Women Attended': 1063,
#   'Registered for PM SWANIDHI CAMP': 215,
#   'People Attended Health Camp': 295,
#   'People Availed Ayushman card camp': 37,
#   'Registration for PM - Ujjwala Yojna': 52,
#   'People for Aadhar card camp': 84,
#   'Total People taking Sankalp Publicly': 1469},
#  {'Vidhan Sabha': 'Dakshin- Pashchim',
#   'Date': '22-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Ward 47 saint marry school tulsi nagar',
#   'Total People Attendance': 2028,
#   'Men Attended': 856,
#   'Women Attended': 1172,
#   'Registered for PM SWANIDHI CAMP': 204,
#   'People Attended Health Camp': 243,
#   'People Availed Ayushman card camp': 51,
#   'Registration for PM - Ujjwala Yojna': 48,
#   'People for Aadhar card camp': 52,
#   'Total People taking Sankalp Publicly': 1626},
#  {'Vidhan Sabha': 'Uttar',
#   'Date': '22-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Hanuman ganj thana',
#   'Total People Attendance': 2168,
#   'Men Attended': 905,
#   'Women Attended': 1263,
#   'Registered for PM SWANIDHI CAMP': 247,
#   'People Attended Health Camp': 315,
#   'People Availed Ayushman card camp': 34,
#   'Registration for PM - Ujjwala Yojna': 62,
#   'People for Aadhar card camp': 58,
#   'Total People taking Sankalp Publicly': 1586},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '23-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Government school bawadiya village',
#   'Total People Attendance': 2531,
#   'Men Attended': 1383,
#   'Women Attended': 1148,
#   'Registered for PM SWANIDHI CAMP': 373,
#   'People Attended Health Camp': 659,
#   'People Availed Ayushman card camp': 98,
#   'Registration for PM - Ujjwala Yojna': 84,
#   'People for Aadhar card camp': 104,
#   'Total People taking Sankalp Publicly': 1854},
#  {'Vidhan Sabha': 'Madhya',
#   'Date': '23-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Ward-20 aajad park manglwara',
#   'Total People Attendance': 2555,
#   'Men Attended': 1352,
#   'Women Attended': 1203,
#   'Registered for PM SWANIDHI CAMP': 278,
#   'People Attended Health Camp': 575,
#   'People Availed Ayushman card camp': 77,
#   'Registration for PM - Ujjwala Yojna': 94,
#   'People for Aadhar card camp': 86,
#   'Total People taking Sankalp Publicly': 1796},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '24-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Bagmungaliya bus stop',
#   'Total People Attendance': 2574,
#   'Men Attended': 1269,
#   'Women Attended': 1305,
#   'Registered for PM SWANIDHI CAMP': 386,
#   'People Attended Health Camp': 697,
#   'People Availed Ayushman card camp': 93,
#   'Registration for PM - Ujjwala Yojna': 82,
#   'People for Aadhar card camp': 125,
#   'Total People taking Sankalp Publicly': 1863},
#  {'Vidhan Sabha': 'Madhya',
#   'Date': '24-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Balvihar ward 19',
#   'Total People Attendance': 2469,
#   'Men Attended': 1252,
#   'Women Attended': 1217,
#   'Registered for PM SWANIDHI CAMP': 352,
#   'People Attended Health Camp': 495,
#   'People Availed Ayushman card camp': 83,
#   'Registration for PM - Ujjwala Yojna': 101,
#   'People for Aadhar card camp': 136,
#   'Total People taking Sankalp Publicly': 1902},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '25-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Ward-54 hitkarni school bagsewaniya',
#   'Total People Attendance': 2565,
#   'Men Attended': 1241,
#   'Women Attended': 1324,
#   'Registered for PM SWANIDHI CAMP': 366,
#   'People Attended Health Camp': 462,
#   'People Availed Ayushman card camp': 114,
#   'Registration for PM - Ujjwala Yojna': 91,
#   'People for Aadhar card camp': 159,
#   'Total People taking Sankalp Publicly': 2106},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '25-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Sardar patel school, karond chouraha',
#   'Total People Attendance': 2705,
#   'Men Attended': 1252,
#   'Women Attended': 1453,
#   'Registered for PM SWANIDHI CAMP': 405,
#   'People Attended Health Camp': 564,
#   'People Availed Ayushman card camp': 108,
#   'Registration for PM - Ujjwala Yojna': 300,
#   'People for Aadhar card camp': 172,
#   'Total People taking Sankalp Publicly': 2217},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '26-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Bagmungliya 16 acre aam ke ped ke pass',
#   'Total People Attendance': 6042,
#   'Men Attended': 2836,
#   'Women Attended': 3206,
#   'Registered for PM SWANIDHI CAMP': 1403,
#   'People Attended Health Camp': 2216,
#   'People Availed Ayushman card camp': 953,
#   'Registration for PM - Ujjwala Yojna': 1206,
#   'People for Aadhar card camp': 1836,
#   'Total People taking Sankalp Publicly': 5056},
#  {'Vidhan Sabha': 'Madhya',
#   'Date': '26-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Ward office, ward 35 berkhedi',
#   'Total People Attendance': 6013,
#   'Men Attended': 3148,
#   'Women Attended': 2865,
#   'Registered for PM SWANIDHI CAMP': 1286,
#   'People Attended Health Camp': 2172,
#   'People Availed Ayushman card camp': 895,
#   'Registration for PM - Ujjwala Yojna': 1156,
#   'People for Aadhar card camp': 1795,
#   'Total People taking Sankalp Publicly': 5162},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '27-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Ward-56 f sector maidan',
#   'Total People Attendance': 6155,
#   'Men Attended': 2986,
#   'Women Attended': 3169,
#   'Registered for PM SWANIDHI CAMP': 1396,
#   'People Attended Health Camp': 2693,
#   'People Availed Ayushman card camp': 968,
#   'Registration for PM - Ujjwala Yojna': 1365,
#   'People for Aadhar card camp': 1896,
#   'Total People taking Sankalp Publicly': 5483},
#  {'Vidhan Sabha': 'Dakshin- Pashchim',
#   'Date': '27-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Ward-31 ward office',
#   'Total People Attendance': 6059,
#   'Men Attended': 3163,
#   'Women Attended': 2896,
#   'Registered for PM SWANIDHI CAMP': 1255,
#   'People Attended Health Camp': 2583,
#   'People Availed Ayushman card camp': 873,
#   'Registration for PM - Ujjwala Yojna': 1296,
#   'People for Aadhar card camp': 1759,
#   'Total People taking Sankalp Publicly': 5297},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '28-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Ward-57 pipaliya painde khan school',
#   'Total People Attendance': 6003,
#   'Men Attended': 2812,
#   'Women Attended': 3191,
#   'Registered for PM SWANIDHI CAMP': 1124,
#   'People Attended Health Camp': 2669,
#   'People Availed Ayushman card camp': 921,
#   'Registration for PM - Ujjwala Yojna': 1006,
#   'People for Aadhar card camp': 1455,
#   'Total People taking Sankalp Publicly': 5689},
#  {'Vidhan Sabha': 'Madhya',
#   'Date': '28-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Ward 45 ward office 125 line shivaji nagar',
#   'Total People Attendance': 6060,
#   'Men Attended': 2873,
#   'Women Attended': 3187,
#   'Registered for PM SWANIDHI CAMP': 1396,
#   'People Attended Health Camp': 2968,
#   'People Availed Ayushman card camp': 1085,
#   'Registration for PM - Ujjwala Yojna': 986,
#   'People for Aadhar card camp': 1365,
#   'Total People taking Sankalp Publicly': 5402},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '29-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Khajuri road nirmal nagar ke pass',
#   'Total People Attendance': 8585,
#   'Men Attended': 3783,
#   'Women Attended': 4802,
#   'Registered for PM SWANIDHI CAMP': 2563,
#   'People Attended Health Camp': 5017,
#   'People Availed Ayushman card camp': 2096,
#   'Registration for PM - Ujjwala Yojna': 1980,
#   'People for Aadhar card camp': 3798,
#   'Total People taking Sankalp Publicly': 7615},
#  {'Vidhan Sabha': 'Uttar',
#   'Date': '29-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Teela jmalpura, hanuman mandir k pas',
#   'Total People Attendance': 8533,
#   'Men Attended': 4231,
#   'Women Attended': 4302,
#   'Registered for PM SWANIDHI CAMP': 2482,
#   'People Attended Health Camp': 4897,
#   'People Availed Ayushman card camp': 2369,
#   'Registration for PM - Ujjwala Yojna': 2185,
#   'People for Aadhar card camp': 3894,
#   'Total People taking Sankalp Publicly': 7234},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '30-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Allahabad bank',
#   'Total People Attendance': 8670,
#   'Men Attended': 3923,
#   'Women Attended': 4747,
#   'Registered for PM SWANIDHI CAMP': 2306,
#   'People Attended Health Camp': 5036,
#   'People Availed Ayushman card camp': 2219,
#   'Registration for PM - Ujjwala Yojna': 1984,
#   'People for Aadhar card camp': 1896,
#   'Total People taking Sankalp Publicly': 7470},
#  {'Vidhan Sabha': 'Madhya',
#   'Date': '30-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Zone office, yatayat park',
#   'Total People Attendance': 8585,
#   'Men Attended': 4125,
#   'Women Attended': 4460,
#   'Registered for PM SWANIDHI CAMP': 2431,
#   'People Attended Health Camp': 4986,
#   'People Availed Ayushman card camp': 2025,
#   'Registration for PM - Ujjwala Yojna': 2127,
#   'People for Aadhar card camp': 2423,
#   'Total People taking Sankalp Publicly': 7254},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '31-12-2023',
#   'Shift': 'Morning',
#   'Location': 'Bda colony ka ground',
#   'Total People Attendance': 10377,
#   'Men Attended': 4854,
#   'Women Attended': 5523,
#   'Registered for PM SWANIDHI CAMP': 2654,
#   'People Attended Health Camp': 5675,
#   'People Availed Ayushman card camp': 2540,
#   'Registration for PM - Ujjwala Yojna': 2876,
#   'People for Aadhar card camp': 3202,
#   'Total People taking Sankalp Publicly': 8031},
#  {'Vidhan Sabha': 'Uttar',
#   'Date': '31-12-2023',
#   'Shift': 'Afternoon',
#   'Location': 'Kaji camp, shahjhanabad',
#   'Total People Attendance': 10334,
#   'Men Attended': 5102,
#   'Women Attended': 5232,
#   'Registered for PM SWANIDHI CAMP': 2543,
#   'People Attended Health Camp': 6023,
#   'People Availed Ayushman card camp': 2704,
#   'Registration for PM - Ujjwala Yojna': 2532,
#   'People for Aadhar card camp': 2813,
#   'Total People taking Sankalp Publicly': 7902},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '01-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Pathar school, ajanta ke pass',
#   'Total People Attendance': 10430,
#   'Men Attended': 5322,
#   'Women Attended': 5108,
#   'Registered for PM SWANIDHI CAMP': 2803,
#   'People Attended Health Camp': 6015,
#   'People Availed Ayushman card camp': 2752,
#   'Registration for PM - Ujjwala Yojna': 2902,
#   'People for Aadhar card camp': 3431,
#   'Total People taking Sankalp Publicly': 8596},
#  {'Vidhan Sabha': 'Uttar',
#   'Date': '01-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Ward 9 ward office, putli ghar ke pass',
#   'Total People Attendance': 10116,
#   'Men Attended': 4803,
#   'Women Attended': 5313,
#   'Registered for PM SWANIDHI CAMP': 2706,
#   'People Attended Health Camp': 5048,
#   'People Availed Ayushman card camp': 2604,
#   'Registration for PM - Ujjwala Yojna': 2795,
#   'People for Aadhar card camp': 2784,
#   'Total People taking Sankalp Publicly': 7817},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '02-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Labour colony',
#   'Total People Attendance': 10443,
#   'Men Attended': 5461,
#   'Women Attended': 4982,
#   'Registered for PM SWANIDHI CAMP': 2705,
#   'People Attended Health Camp': 7900,
#   'People Availed Ayushman card camp': 2542,
#   'Registration for PM - Ujjwala Yojna': 2819,
#   'People for Aadhar card camp': 2904,
#   'Total People taking Sankalp Publicly': 8023},
#  {'Vidhan Sabha': 'Dakshin Pashchim',
#   'Date': '02-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Sanjeevani clinic naya basera',
#   'Total People Attendance': 10148,
#   'Men Attended': 4625,
#   'Women Attended': 5523,
#   'Registered for PM SWANIDHI CAMP': 2847,
#   'People Attended Health Camp': 7819,
#   'People Availed Ayushman card camp': 2406,
#   'Registration for PM - Ujjwala Yojna': 2755,
#   'People for Aadhar card camp': 2513,
#   'Total People taking Sankalp Publicly': 7350},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '03-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Kokta samudayik bhawan',
#   'Total People Attendance': 10198,
#   'Men Attended': 5442,
#   'Women Attended': 4756,
#   'Registered for PM SWANIDHI CAMP': 1823,
#   'People Attended Health Camp': 5768,
#   'People Availed Ayushman card camp': 1580,
#   'Registration for PM - Ujjwala Yojna': 1676,
#   'People for Aadhar card camp': 1721,
#   'Total People taking Sankalp Publicly': 7224},
#  {'Vidhan Sabha': 'Huzur',
#   'Date': '03-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Banjari duessehra maidan',
#   'Total People Attendance': 10029,
#   'Men Attended': 5673,
#   'Women Attended': 4356,
#   'Registered for PM SWANIDHI CAMP': 1736,
#   'People Attended Health Camp': 5686,
#   'People Availed Ayushman card camp': 1453,
#   'Registration for PM - Ujjwala Yojna': 1572,
#   'People for Aadhar card camp': 1285,
#   'Total People taking Sankalp Publicly': 7524},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '04-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Santnami nagar chouraha',
#   'Total People Attendance': 10413,
#   'Men Attended': 5896,
#   'Women Attended': 4517,
#   'Registered for PM SWANIDHI CAMP': 1426,
#   'People Attended Health Camp': 4685,
#   'People Availed Ayushman card camp': 1681,
#   'Registration for PM - Ujjwala Yojna': 1364,
#   'People for Aadhar card camp': 1328,
#   'Total People taking Sankalp Publicly': 8026},
#  {'Vidhan Sabha': 'Dakshin Pashchim',
#   'Date': '04-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Ambedkar park ambedkar naga',
#   'Total People Attendance': 10390,
#   'Men Attended': 6125,
#   'Women Attended': 4265,
#   'Registered for PM SWANIDHI CAMP': 1253,
#   'People Attended Health Camp': 3264,
#   'People Availed Ayushman card camp': 1480,
#   'Registration for PM - Ujjwala Yojna': 1276,
#   'People for Aadhar card camp': 1521,
#   'Total People taking Sankalp Publicly': 7964},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '05-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Adarsh nagar sai mandir k paas',
#   'Total People Attendance': 8021,
#   'Men Attended': 3265,
#   'Women Attended': 4756,
#   'Registered for PM SWANIDHI CAMP': 221,
#   'People Attended Health Camp': 1836,
#   'People Availed Ayushman card camp': 453,
#   'Registration for PM - Ujjwala Yojna': 576,
#   'People for Aadhar card camp': 603,
#   'Total People taking Sankalp Publicly': 4776},
#  {'Vidhan Sabha': 'Huzur ',
#   'Date': '05-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Sumitra parisar 80 ft road ward 84',
#   'Total People Attendance': 8048,
#   'Men Attended': 3653,
#   'Women Attended': 4395,
#   'Registered for PM SWANIDHI CAMP': 232,
#   'People Attended Health Camp': 1735,
#   'People Availed Ayushman card camp': 326,
#   'Registration for PM - Ujjwala Yojna': 562,
#   'People for Aadhar card camp': 494,
#   'Total People taking Sankalp Publicly': 5652},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '06-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Saraswati school',
#   'Total People Attendance': 7027,
#   'Men Attended': 2832,
#   'Women Attended': 4195,
#   'Registered for PM SWANIDHI CAMP': 196,
#   'People Attended Health Camp': 1959,
#   'People Availed Ayushman card camp': 286,
#   'Registration for PM - Ujjwala Yojna': 372,
#   'People for Aadhar card camp': 405,
#   'Total People taking Sankalp Publicly': 5062},
#  {'Vidhan Sabha': 'Dakshin Pashchim',
#   'Date': '06-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Nai sabri nagar, ward 29',
#   'Total People Attendance': 7038,
#   'Men Attended': 2923,
#   'Women Attended': 4115,
#   'Registered for PM SWANIDHI CAMP': 203,
#   'People Attended Health Camp': 1856,
#   'People Availed Ayushman card camp': 245,
#   'Registration for PM - Ujjwala Yojna': 356,
#   'People for Aadhar card camp': 356,
#   'Total People taking Sankalp Publicly': 5163},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '07-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Ward office ward 72 bhanpur',
#   'Total People Attendance': 6211,
#   'Men Attended': 2454,
#   'Women Attended': 3757,
#   'Registered for PM SWANIDHI CAMP': 167,
#   'People Attended Health Camp': 1762,
#   'People Availed Ayushman card camp': 245,
#   'Registration for PM - Ujjwala Yojna': 312,
#   'People for Aadhar card camp': 376,
#   'Total People taking Sankalp Publicly': 4867},
#  {'Vidhan Sabha': 'Madhya',
#   'Date': '07-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'New subhash nagar community hall',
#   'Total People Attendance': 6075,
#   'Men Attended': 2786,
#   'Women Attended': 3289,
#   'Registered for PM SWANIDHI CAMP': 181,
#   'People Attended Health Camp': 1843,
#   'People Availed Ayushman card camp': 296,
#   'Registration for PM - Ujjwala Yojna': 365,
#   'People for Aadhar card camp': 401,
#   'Total People taking Sankalp Publicly': 5123},
#  {'Vidhan Sabha': 'Dakshin Pashchim',
#   'Date': '08-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Ward office ward 25 banganga',
#   'Total People Attendance': 8287,
#   'Men Attended': 3564,
#   'Women Attended': 4723,
#   'Registered for PM SWANIDHI CAMP': 438,
#   'People Attended Health Camp': 2239,
#   'People Availed Ayushman card camp': 464,
#   'Registration for PM - Ujjwala Yojna': 541,
#   'People for Aadhar card camp': 586,
#   'Total People taking Sankalp Publicly': 5876},
#  {'Vidhan Sabha': 'Madhya',
#   'Date': '09-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Gauri shankar kaushal mangal bhawan janta quarter',
#   'Total People Attendance': 6416,
#   'Men Attended': 2463,
#   'Women Attended': 3953,
#   'Registered for PM SWANIDHI CAMP': 269,
#   'People Attended Health Camp': 1785,
#   'People Availed Ayushman card camp': 462,
#   'Registration for PM - Ujjwala Yojna': 327,
#   'People for Aadhar card camp': 405,
#   'Total People taking Sankalp Publicly': 4125},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '10-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Near krond square, canara bank',
#   'Total People Attendance': 5048,
#   'Men Attended': 2152,
#   'Women Attended': 2896,
#   'Registered for PM SWANIDHI CAMP': 205,
#   'People Attended Health Camp': 1423,
#   'People Availed Ayushman card camp': 219,
#   'Registration for PM - Ujjwala Yojna': 331,
#   'People for Aadhar card camp': 352,
#   'Total People taking Sankalp Publicly': 3624},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '10-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Shakha ground, vikash nagar',
#   'Total People Attendance': 5214,
#   'Men Attended': 2301,
#   'Women Attended': 2913,
#   'Registered for PM SWANIDHI CAMP': 212,
#   'People Attended Health Camp': 1423,
#   'People Availed Ayushman card camp': 293,
#   'Registration for PM - Ujjwala Yojna': 345,
#   'People for Aadhar card camp': 369,
#   'Total People taking Sankalp Publicly': 3631},
#  {'Vidhan Sabha': 'Huzur',
#   'Date': '11-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Bus stop, gandhi nagar',
#   'Total People Attendance': 6742,
#   'Men Attended': 2753,
#   'Women Attended': 3989,
#   'Registered for PM SWANIDHI CAMP': 386,
#   'People Attended Health Camp': 1896,
#   'People Availed Ayushman card camp': 398,
#   'Registration for PM - Ujjwala Yojna': 452,
#   'People for Aadhar card camp': 474,
#   'Total People taking Sankalp Publicly': 5339},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '11-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Shankrachary nagar',
#   'Total People Attendance': 6869,
#   'Men Attended': 2895,
#   'Women Attended': 3974,
#   'Registered for PM SWANIDHI CAMP': 341,
#   'People Attended Health Camp': 1785,
#   'People Availed Ayushman card camp': 421,
#   'Registration for PM - Ujjwala Yojna': 512,
#   'People for Aadhar card camp': 406,
#   'Total People taking Sankalp Publicly': 5304},
#  {'Vidhan Sabha': 'Dakshin Pashchim',
#   'Date': '12-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Arjun nagar',
#   'Total People Attendance': 6919,
#   'Men Attended': 2635,
#   'Women Attended': 4284,
#   'Registered for PM SWANIDHI CAMP': 379,
#   'People Attended Health Camp': 1987,
#   'People Availed Ayushman card camp': 479,
#   'Registration for PM - Ujjwala Yojna': 535,
#   'People for Aadhar card camp': 682,
#   'Total People taking Sankalp Publicly': 4964},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '12-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Chhola dashehra maidan',
#   'Total People Attendance': 6740,
#   'Men Attended': 2785,
#   'Women Attended': 3955,
#   'Registered for PM SWANIDHI CAMP': 365,
#   'People Attended Health Camp': 1895,
#   'People Availed Ayushman card camp': 345,
#   'Registration for PM - Ujjwala Yojna': 496,
#   'People for Aadhar card camp': 463,
#   'Total People taking Sankalp Publicly': 4621},
#  {'Vidhan Sabha': 'Dakshin Pashchim',
#   'Date': '13-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Bhadbhada, suraj nagar',
#   'Total People Attendance': 6744,
#   'Men Attended': 2789,
#   'Women Attended': 3955,
#   'Registered for PM SWANIDHI CAMP': 395,
#   'People Attended Health Camp': 1965,
#   'People Availed Ayushman card camp': 486,
#   'Registration for PM - Ujjwala Yojna': 501,
#   'People for Aadhar card camp': 576,
#   'Total People taking Sankalp Publicly': 4986},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '13-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Janta quarter',
#   'Total People Attendance': 6676,
#   'Men Attended': 2635,
#   'Women Attended': 4041,
#   'Registered for PM SWANIDHI CAMP': 301,
#   'People Attended Health Camp': 1795,
#   'People Availed Ayushman card camp': 395,
#   'Registration for PM - Ujjwala Yojna': 453,
#   'People for Aadhar card camp': 505,
#   'Total People taking Sankalp Publicly': 4796},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '14-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Infront of ward office, ward 37',
#   'Total People Attendance': 9336,
#   'Men Attended': 4302,
#   'Women Attended': 5034,
#   'Registered for PM SWANIDHI CAMP': 564,
#   'People Attended Health Camp': 2345,
#   'People Availed Ayushman card camp': 676,
#   'Registration for PM - Ujjwala Yojna': 504,
#   'People for Aadhar card camp': 764,
#   'Total People taking Sankalp Publicly': 5674},
#  {'Vidhan Sabha': 'Dakshin Pashchim',
#   'Date': '15-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Malviya nagar',
#   'Total People Attendance': 6883,
#   'Men Attended': 2896,
#   'Women Attended': 3987,
#   'Registered for PM SWANIDHI CAMP': 365,
#   'People Attended Health Camp': 1801,
#   'People Availed Ayushman card camp': 406,
#   'Registration for PM - Ujjwala Yojna': 498,
#   'People for Aadhar card camp': 536,
#   'Total People taking Sankalp Publicly': 4934},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '15-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Durga mandir k pas, devki nagar',
#   'Total People Attendance': 6851,
#   'Men Attended': 3156,
#   'Women Attended': 3695,
#   'Registered for PM SWANIDHI CAMP': 406,
#   'People Attended Health Camp': 1826,
#   'People Availed Ayushman card camp': 419,
#   'Registration for PM - Ujjwala Yojna': 436,
#   'People for Aadhar card camp': 672,
#   'Total People taking Sankalp Publicly': 4816},
#  {'Vidhan Sabha': 'Huzur',
#   'Date': '16-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Ward office ward 82 gehukheda',
#   'Total People Attendance': 6685,
#   'Men Attended': 2896,
#   'Women Attended': 3789,
#   'Registered for PM SWANIDHI CAMP': 412,
#   'People Attended Health Camp': 1753,
#   'People Availed Ayushman card camp': 451,
#   'Registration for PM - Ujjwala Yojna': 498,
#   'People for Aadhar card camp': 782,
#   'Total People taking Sankalp Publicly': 4796},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '16-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Vishwa karma nagar karond',
#   'Total People Attendance': 6782,
#   'Men Attended': 2796,
#   'Women Attended': 3986,
#   'Registered for PM SWANIDHI CAMP': 509,
#   'People Attended Health Camp': 1896,
#   'People Availed Ayushman card camp': 473,
#   'Registration for PM - Ujjwala Yojna': 501,
#   'People for Aadhar card camp': 804,
#   'Total People taking Sankalp Publicly': 4832},
#  {'Vidhan Sabha': ' Dakshin Pashchim',
#   'Date': '17-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Durga nagar',
#   'Total People Attendance': 6862,
#   'Men Attended': 2875,
#   'Women Attended': 3987,
#   'Registered for PM SWANIDHI CAMP': 403,
#   'People Attended Health Camp': 1976,
#   'People Availed Ayushman card camp': 385,
#   'Registration for PM - Ujjwala Yojna': 498,
#   'People for Aadhar card camp': 507,
#   'Total People taking Sankalp Publicly': 4981},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '17-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Roop nagar',
#   'Total People Attendance': 6777,
#   'Men Attended': 3102,
#   'Women Attended': 3675,
#   'Registered for PM SWANIDHI CAMP': 376,
#   'People Attended Health Camp': 1896,
#   'People Availed Ayushman card camp': 343,
#   'Registration for PM - Ujjwala Yojna': 446,
#   'People for Aadhar card camp': 537,
#   'Total People taking Sankalp Publicly': 4754},
#  {'Vidhan Sabha': 'Dakshin Pashchim',
#   'Date': '18-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Sanjeevni clinic ke pas, green mzaar',
#   'Total People Attendance': 6815,
#   'Men Attended': 2863,
#   'Women Attended': 3952,
#   'Registered for PM SWANIDHI CAMP': 375,
#   'People Attended Health Camp': 2103,
#   'People Availed Ayushman card camp': 576,
#   'Registration for PM - Ujjwala Yojna': 598,
#   'People for Aadhar card camp': 485,
#   'Total People taking Sankalp Publicly': 4796},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '18-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Shiv mandir ke pas subhash colony',
#   'Total People Attendance': 6858,
#   'Men Attended': 2963,
#   'Women Attended': 3895,
#   'Registered for PM SWANIDHI CAMP': 305,
#   'People Attended Health Camp': 1985,
#   'People Availed Ayushman card camp': 469,
#   'Registration for PM - Ujjwala Yojna': 483,
#   'People for Aadhar card camp': 403,
#   'Total People taking Sankalp Publicly': 4296},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '18-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Chourasiya samaj mandir ke pas',
#   'Total People Attendance': 6932,
#   'Men Attended': 3136,
#   'Women Attended': 3796,
#   'Registered for PM SWANIDHI CAMP': 398,
#   'People Attended Health Camp': 2025,
#   'People Availed Ayushman card camp': 477,
#   'Registration for PM - Ujjwala Yojna': 512,
#   'People for Aadhar card camp': 426,
#   'Total People taking Sankalp Publicly': 4963},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '18-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Ektapuri maidan',
#   'Total People Attendance': 6850,
#   'Men Attended': 3152,
#   'Women Attended': 3698,
#   'Registered for PM SWANIDHI CAMP': 416,
#   'People Attended Health Camp': 1977,
#   'People Availed Ayushman card camp': 471,
#   'Registration for PM - Ujjwala Yojna': 493,
#   'People for Aadhar card camp': 437,
#   'Total People taking Sankalp Publicly': 5012},
#  {'Vidhan Sabha': 'Dakshin Pashchim',
#   'Date': '19-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Aaganwari kendra sunhari baag',
#   'Total People Attendance': 6617,
#   'Men Attended': 2632,
#   'Women Attended': 3985,
#   'Registered for PM SWANIDHI CAMP': 296,
#   'People Attended Health Camp': 1782,
#   'People Availed Ayushman card camp': 432,
#   'Registration for PM - Ujjwala Yojna': 525,
#   'People for Aadhar card camp': 495,
#   'Total People taking Sankalp Publicly': 4365},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '19-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Jain mandir k pas',
#   'Total People Attendance': 6632,
#   'Men Attended': 2836,
#   'Women Attended': 3796,
#   'Registered for PM SWANIDHI CAMP': 365,
#   'People Attended Health Camp': 1865,
#   'People Availed Ayushman card camp': 426,
#   'Registration for PM - Ujjwala Yojna': 465,
#   'People for Aadhar card camp': 367,
#   'Total People taking Sankalp Publicly': 4632},
#  {'Vidhan Sabha': 'Govindpura',
#   'Date': '19-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Kolua gaon',
#   'Total People Attendance': 7757,
#   'Men Attended': 3396,
#   'Women Attended': 4361,
#   'Registered for PM SWANIDHI CAMP': 426,
#   'People Attended Health Camp': 2152,
#   'People Availed Ayushman card camp': 517,
#   'Registration for PM - Ujjwala Yojna': 625,
#   'People for Aadhar card camp': 634,
#   'Total People taking Sankalp Publicly': 5415},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '19-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Parihar chouraha',
#   'Total People Attendance': 7938,
#   'Men Attended': 3153,
#   'Women Attended': 4785,
#   'Registered for PM SWANIDHI CAMP': 513,
#   'People Attended Health Camp': 2236,
#   'People Availed Ayushman card camp': 621,
#   'Registration for PM - Ujjwala Yojna': 698,
#   'People for Aadhar card camp': 632,
#   'Total People taking Sankalp Publicly': 5512},
#  {'Vidhan Sabha': 'Huzur',
#   'Date': '20-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Ward office ward 6 vijay nagar',
#   'Total People Attendance': 7755,
#   'Men Attended': 3103,
#   'Women Attended': 4652,
#   'Registered for PM SWANIDHI CAMP': 450,
#   'People Attended Health Camp': 2365,
#   'People Availed Ayushman card camp': 485,
#   'Registration for PM - Ujjwala Yojna': 596,
#   'People for Aadhar card camp': 603,
#   'Total People taking Sankalp Publicly': 5965},
#  {'Vidhan Sabha': 'Dakshin Pashchim',
#   'Date': '20-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Rahul nagar',
#   'Total People Attendance': 7883,
#   'Men Attended': 2896,
#   'Women Attended': 4987,
#   'Registered for PM SWANIDHI CAMP': 419,
#   'People Attended Health Camp': 2302,
#   'People Availed Ayushman card camp': 536,
#   'Registration for PM - Ujjwala Yojna': 488,
#   'People for Aadhar card camp': 632,
#   'Total People taking Sankalp Publicly': 5653},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '20-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Ward office ward 41',
#   'Total People Attendance': 7491,
#   'Men Attended': 2796,
#   'Women Attended': 4695,
#   'Registered for PM SWANIDHI CAMP': 563,
#   'People Attended Health Camp': 2015,
#   'People Availed Ayushman card camp': 463,
#   'Registration for PM - Ujjwala Yojna': 511,
#   'People for Aadhar card camp': 588,
#   'Total People taking Sankalp Publicly': 5415},
#  {'Vidhan Sabha': 'Narela',
#   'Date': '20-01-2024',
#   'Shift': 'Afternoon',
#   'Location': 'Chanakyapuri maidan',
#   'Total People Attendance': 7589,
#   'Men Attended': 3020,
#   'Women Attended': 4569,
#   'Registered for PM SWANIDHI CAMP': 517,
#   'People Attended Health Camp': 2119,
#   'People Availed Ayushman card camp': 465,
#   'Registration for PM - Ujjwala Yojna': 585,
#   'People for Aadhar card camp': 596,
#   'Total People taking Sankalp Publicly': 5635},
#  {'Vidhan Sabha': 'Huzur',
#   'Date': '23-01-2024',
#   'Shift': 'Morning',
#   'Location': 'Barai gouri shankar parisar bda ke samne',
#   'Total People Attendance': 7815,
#   'Men Attended': 3126,
#   'Women Attended': 4689,
#   'Registered for PM SWANIDHI CAMP': 435,
#   'People Attended Health Camp': 2296,
#   'People Availed Ayushman card camp': 559,
#   'Registration for PM - Ujjwala Yojna': 592,
#   'People for Aadhar card camp': 652,
#   'Total People taking Sankalp Publicly': 5634}]

# %%
bhopal_cord = 23.253374, 77.426899
bhopal_map = folium.Map(location=bhopal_cord, zoom_start=12)

camp = plugins.MarkerCluster().add_to(bhopal_map)

for lat, long, row_dict in zip(df['Latitude'], df['Longitude'], vs_dict):
    label = (
        f"VidhanSabha:- {row_dict['Vidhan Sabha']}<br>"
        f"Date:- {row_dict['Date']}<br>"
        f"Location:- {row_dict['Location']}<br>"
        f"Total People Attendance:- {row_dict['Total People Attendance']}"
    )
    
    folium.Marker(
        location=[lat, long],
        icon=None,
        popup=label
    ).add_to(camp)

bhopal_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_933061221f4571cb545979e90226de1e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_933061221f4571cb545979e90226de1e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_933061221f4571cb545979e90226de1e = L.map(
#                 &quot;map_933061221f4571cb545979e90226de1e&quot;,
#                 {
#                     center: [23.253374, 77.426899],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_601de536ca13a886dfe6e510807eae42 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_601de536ca13a886dfe6e510807eae42.addTo(map_933061221f4571cb545979e90226de1e);
#
#             var marker_cluster_d742e6d94d4e877fbf344ca00db07cb7 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_e23ce8dcc63bb16172fd3e73d3957f84 = L.marker(
#                 [23.269873, 77.327614],
#                 {}
#             ).addTo(marker_cluster_d742e6d94d4e877fbf344ca00db07cb7);
#
#
#         var popup_7beabef7f1f264d4309d9223b1c2e467 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd1636811367e715d9890c19b4bb99c5 = $(`&lt;div id=&quot;html_bd1636811367e715d9890c19b4bb99c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VidhanSabha:- Huzur&lt;br&gt;Date:- 17-12-2023&lt;br&gt;Location:- Sehore naka visarjan ghat&lt;br&gt;Total People Attendance:- 2285&lt;/div&gt;`)[0];
#                 popup_7beabef7f1f264d4309d9223b1c2e467.setContent(html_bd1636811367e715d9890c19b4bb99c5);
#
#
#
#         marker_e23ce8dcc63bb16172fd3e73d3957f84.bindPopup(popup_7beabef7f1f264d4309d9223b1c2e467)
#         ;
#
#
#
#
#             var marker_854e9637efe5c25db73e8c9cc0dabeca = L.marker(
#                 [23.272666, 77.33677],
#                 {}
#             ).addTo(marker_cluster_d742e6d94d4e877fbf344ca00db07cb7);
#
#
#         var popup_9afb2bbb30fdfc94ed04c2ff6e1e074d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_14c287b18f3bf13c441579f11d0b65be = $(`&lt;div id=&quot;html_14c287b18f3bf13c441579f11d0b65be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VidhanSabha:- Huzur&lt;br&gt;Date:- 17-12-2023&lt;br&gt;Location:- Dashahera maidan school ke pass&lt;br&gt;Total People Attendance:- 2050&lt;/div&gt;`)[0];
#                 popup_9afb2bbb30fdfc94ed04c2ff6e1e074d.setContent(html_14c287b18f3bf13c441579f11d0b65be);
#
#
#
#         marker_854e9637efe5c25db73e8c9cc0dabeca.bindPopup(popup_9afb2bbb30fdfc94ed04c2ff6e1e074d)
#         ;
#
#
#
#
#             var marker_a0a470cf73212ca5ae95902514f9a428 = L.marker(
#                 [23.271694, 77.379792],
#                 {}
#             ).addTo(marker_cluster_d742e6d94d4e877fbf344ca00db07cb7);
#
#
#         var popup_49e60adacb26b415c7c6dc6cfe7c2274 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_faed5d4166e53330c1f6da9f7541e3ca = $(`&lt;div id=&quot;html_faed5d4166e53330c1f6da9f7541e3ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VidhanSabha:- Uttar&lt;br&gt;Date:- 18-12-2023&lt;br&gt;Location:- Yogseva kendra&lt;br&gt;Total People Attendance:- 2104&lt;/div&gt;`)[0];
#                 popup_49e60adacb26b415c7c6dc6cfe7c2274.setContent(html_faed5d4166e53330c1f6da9f7541e3ca);
#
#
#
#         marker_a0a470cf73212ca5ae95902514f9a428.bindPopup(popup_49e60adacb26b415c7c6dc6cfe7c2274)
#         ;
#
#
#
#
#             var marker_494337f21d01de4930b07176a746fbee = L.marker(
#                 [23.247364, 77.436113],
#                 {}
#             ).addTo(marker_cluster_d742e6d94d4e877fbf344ca00db07cb7);
#
#
#         var popup_a3600d5d73623650052ec8db94763eee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c360c09797e1e80cd5575c5865ff619 = $(`&lt;div id=&quot;html_4c360c09797e1e80cd5575c5865ff619&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VidhanSabha:- Narela&lt;br&gt;Date:- 18-12-2023&lt;br&gt;Location:- Acharya narendra nagar&lt;br&gt;Total People Attendance:- 2109&lt;/div&gt;`)[0];

# %%
# save map
bhopal_map.save('VBSY_Bhopal_Camp_Details_Map.html')

# %% [markdown]
# ### Thank you
# ## Author
#
# [Neelesh Chidar](https://www.linkedin.com/in/neeleshchidar37/)
